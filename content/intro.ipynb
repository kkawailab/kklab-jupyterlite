# %% [markdown]
# # JupyterLite へようこそ 🚀
#
# このノートブックはブラウザの中だけで動く **JupyterLite** 上で実行されています。
# サーバーは不要で、Python カーネル（Pyodide）は WebAssembly としてブラウザ内で動作します。
#
# 下のセルを選択して `Shift + Enter` で実行してみてください。

# %%
print("こんにちは、JupyterLite!")
# Out:
# こんにちは、JupyterLite!

# %%
import sys
print(f"Python バージョン: {sys.version}")
print(f"プラットフォーム: {sys.platform}")
# Out:
# Python バージョン: 3.11.2 (main, Apr  8 2026, 01:58:00) [GCC 12.2.0]
# プラットフォーム: linux

# %%
# 簡単な計算もできます
total = sum(range(1, 101))
print(f"1 から 100 までの合計: {total}")
# Out:
# 1 から 100 までの合計: 5050

# %% [markdown]
# ## パッケージのインストール
#
# `%pip install` マジックコマンドで、多くの純 Python パッケージや
# Pyodide 対応パッケージ（numpy, pandas, matplotlib など）を追加できます。

# %%
# %pip install numpy
import numpy as np
np.arange(10) ** 2
# Out:
# Requirement already satisfied: numpy in /tmp/claude-1000/-home-katzkawai-kklab-jupyterlite/dd90e4cc-225c-4f5f-aa85-8fb2a7771184/scratchpad/venv/lib/python3.11/site-packages (2.4.6)
# Note: you may need to restart the kernel to use updated packages.
# array([ 0,  1,  4,  9, 16, 25, 36, 49, 64, 81])
