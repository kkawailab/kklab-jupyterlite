# %% [markdown]
# # JupyterLite で学ぶ Leaflet / folium 入門チュートリアル
#
# このノートブックは、**JupyterLite（ブラウザだけで動く Jupyter 環境）** 上で、
# JavaScript の地図ライブラリ **Leaflet** を Python から扱うためのラッパーライブラリ **folium** を使い、
# インタラクティブな地図を表示・操作する方法を学ぶためのチュートリアルです。
#
# 主な内容：
# - folium / Leaflet の概要
# - 基本の地図表示
# - マーカーとポップアップ
# - 複数地点の可視化（ループ・DataFrame）
# - タイルレイヤの変更
# - GeoJSON の表示
# - ミニ演習
#
# ※ JupyterLite 上で folium を利用するために、純 Python パッケージとして `micropip` からインストールしてみます。

# %% [markdown]
# ## 0. 環境準備（JupyterLite 用）
#
# このノートブックは **JupyterLite（Pyodide）** を想定しています。
#
# まず、folium をインストールし、必要なライブラリをインポートします。
# ※ ネットワーク制限や環境によってはインストールに失敗することがあります。

# %%
# folium は純 Python パッケージのため、micropip でインストールを試みます。
try:
    import folium
except ImportError:
    try:
        import micropip
        await micropip.install("folium")
        import folium
    except Exception as e:
        print("folium のインストールに失敗しました:", e)
        print("この環境で folium が利用できない場合があります。")

import pandas as pd
import numpy as np

print("ライブラリの読み込みが完了しました（エラーが出ていなければ OK）。")
# Out:
# ライブラリの読み込みが完了しました（エラーが出ていなければ OK）。

# %% [markdown]
# ## 1. folium と Leaflet の概要
#
# **Leaflet** は、ブラウザ上で動作する軽量な JavaScript 製の地図ライブラリです。
# OpenStreetMap などのタイル地図をベースに、マーカーやポリゴン・ポリラインなどを簡単に描画できます。
#
# **folium** は、この Leaflet を Python から扱うためのラッパーライブラリで、
# Jupyter Notebook / JupyterLite の中でインタラクティブな地図を表示できます。
#
# folium の基本的な使い方は：
# 1. `folium.Map` オブジェクトを作る
# 2. `folium.Marker` などで要素を追加
# 3. Notebook 上でオブジェクトを表示
# という流れです。

# %% [markdown]
# ## 2. 基本の地図表示
#
# まずは、もっとも基本的な「地図を 1 枚表示する」ことから始めます。
#
# ここでは例として、名古屋市瑞穂区滝子町にある名古屋市立大学経済学部付近の緯度経度（35.13, 136.93 あたり）を中心に表示してみます。

# %% [markdown]
# ### 2.1 シンプルな地図

# %%
# 名古屋市立大学経済学部（滝子キャンパス）付近の座標（緯度・経度）
center = [35.1330, 136.9264]

m = folium.Map(location=center, zoom_start=12)

# Notebook 上で地図オブジェクトを評価すると、HTML として表示されます
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bc358ba47ae7b3b580f5319bcf1f907a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bc358ba47ae7b3b580f5319bcf1f907a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bc358ba47ae7b3b580f5319bcf1f907a = L.map(
#                 &quot;map_bc358ba47ae7b3b580f5319bcf1f907a&quot;,
#                 {
#                     center: [35.133, 136.9264],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_635325ee7ea5064b3c92408467f7ebcc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_635325ee7ea5064b3c92408467f7ebcc.addTo(map_bc358ba47ae7b3b580f5319bcf1f907a);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 2章 練習問題
#
# 1. 自分の住んでいる地域、または行ってみたい都市の緯度・経度を調べて、その地点を中心とした地図を表示しなさい。
# 2. `zoom_start` の値を 5, 10, 15 などに変えて、ズームレベルの違いを体験しなさい。
# 3. 世界地図レベル（例：`location=[0, 0], zoom_start=2`）で表示した地図も試し、日本との位置関係を確認しなさい。

# %% [markdown]
# ## 3. マーカーとポップアップ
#
# 地図に「印（ピン）」を立てるには、`folium.Marker` を使います。
# クリックしたときに表示されるポップアップ文字列も簡単に設定できます。

# %% [markdown]
# ### 3.1 名古屋市立大学経済学部にマーカーを立てる例

# %%
# 名古屋市立大学経済学部
ncu_economics = [35.1330, 136.9264]

m = folium.Map(location=center, zoom_start=14)
folium.Marker(
    location=ncu_economics,
    popup="名古屋市立大学経済学部",
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_27df6b6750c631c70b64cce4effa3b34 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_27df6b6750c631c70b64cce4effa3b34&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_27df6b6750c631c70b64cce4effa3b34 = L.map(
#                 &quot;map_27df6b6750c631c70b64cce4effa3b34&quot;,
#                 {
#                     center: [35.133, 136.9264],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2537d86abfbbbab5ab534a980036d52f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2537d86abfbbbab5ab534a980036d52f.addTo(map_27df6b6750c631c70b64cce4effa3b34);
#
#
#             var marker_48586170b9477b0f69956813a5db1ad7 = L.marker(
#                 [35.133, 136.9264],
#                 {
# }
#             ).addTo(map_27df6b6750c631c70b64cce4effa3b34);
#
#
#         var popup_e5972d3f6327d0c27bdf814228a3791f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_67350007968fe25489b53f07cbd47c6e = $(`&lt;div id=&quot;html_67350007968fe25489b53f07cbd47c6e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;名古屋市立大学経済学部&lt;/div&gt;`)[0];
#                 popup_e5972d3f6327d0c27bdf814228a3791f.setContent(html_67350007968fe25489b53f07cbd47c6e);
#
#
#
#         marker_48586170b9477b0f69956813a5db1ad7.bindPopup(popup_e5972d3f6327d0c27bdf814228a3791f)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 3.2 複数のマーカーを追加する
#
# 複数の地点をリストで用意して、for ループでまとめてマーカーを追加してみます。

# %%
points = [
    {"name": "名古屋市立大学経済学部", "lat": 35.1330, "lon": 136.9264},
    {"name": "金山駅", "lat": 35.1438, "lon": 136.9005},
    {"name": "熱田神宮", "lat": 35.1281, "lon": 136.9077},
]

m = folium.Map(location=center, zoom_start=12)

for p in points:
    folium.Marker(
        location=[p["lat"], p["lon"]],
        popup=p["name"],
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2b2f961bd598aee559b4e859d50efee7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2b2f961bd598aee559b4e859d50efee7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2b2f961bd598aee559b4e859d50efee7 = L.map(
#                 &quot;map_2b2f961bd598aee559b4e859d50efee7&quot;,
#                 {
#                     center: [35.133, 136.9264],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_91a6cdbdbe0cf168a5e5acb1bb25f1be = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_91a6cdbdbe0cf168a5e5acb1bb25f1be.addTo(map_2b2f961bd598aee559b4e859d50efee7);
#
#
#             var marker_e75b63478acbb1b597a57f3dff425108 = L.marker(
#                 [35.133, 136.9264],
#                 {
# }
#             ).addTo(map_2b2f961bd598aee559b4e859d50efee7);
#
#
#         var popup_132395680c07a89b1dcb1cc463ff224b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f60f12e5f58b8bf760b6fb3724a1ef07 = $(`&lt;div id=&quot;html_f60f12e5f58b8bf760b6fb3724a1ef07&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;名古屋市立大学経済学部&lt;/div&gt;`)[0];
#                 popup_132395680c07a89b1dcb1cc463ff224b.setContent(html_f60f12e5f58b8bf760b6fb3724a1ef07);
#
#
#
#         marker_e75b63478acbb1b597a57f3dff425108.bindPopup(popup_132395680c07a89b1dcb1cc463ff224b)
#         ;
#
#
#
#
#             var marker_21b28381f8294cebbfe7f94a5e85e461 = L.marker(
#                 [35.1438, 136.9005],
#                 {
# }
#             ).addTo(map_2b2f961bd598aee559b4e859d50efee7);
#
#
#         var popup_300d758a1d304a8dc5e5eb914d121dca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c5741922c62dd1a701ef5673813da2da = $(`&lt;div id=&quot;html_c5741922c62dd1a701ef5673813da2da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;金山駅&lt;/div&gt;`)[0];
#                 popup_300d758a1d304a8dc5e5eb914d121dca.setContent(html_c5741922c62dd1a701ef5673813da2da);
#
#
#
#         marker_21b28381f8294cebbfe7f94a5e85e461.bindPopup(popup_300d758a1d304a8dc5e5eb914d121dca)
#         ;
#
#
#
#
#             var marker_cb1e3d842ed9d12e3bfae49848142124 = L.marker(
#                 [35.1281, 136.9077],
#                 {
# }
#             ).addTo(map_2b2f961bd598aee559b4e859d50efee7);
#
#
#         var popup_d1d3e38d9a7946d5cfffd4ac4981709d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_228a4ea7fad4dbf584d6364d3c352d8d = $(`&lt;div id=&quot;html_228a4ea7fad4dbf584d6364d3c352d8d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;熱田神宮&lt;/div&gt;`)[0];
#                 popup_d1d3e38d9a7946d5cfffd4ac4981709d.setContent(html_228a4ea7fad4dbf584d6364d3c352d8d);
#
#
#
#         marker_cb1e3d842ed9d12e3bfae49848142124.bindPopup(popup_d1d3e38d9a7946d5cfffd4ac4981709d)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 3章 練習問題
#
# 1. 自分の好きなスポット（3〜5か所）の名称と緯度経度を調べ、リストや DataFrame を使ってまとめてマーカーを表示しなさい。
# 2. `popup` に日本語の説明文をもう少し長めに入れてみて、どのように表示されるか確認しなさい。
# 3. `tooltip` 引数を使うと、マーカーにマウスを乗せたときに表示される短いテキストを指定できます。`tooltip` を試してみなさい。

# %% [markdown]
# ## 4. pandas DataFrame からマーカーを作る
#
# 地点情報が DataFrame として手元にある場合、行をループしながらマーカーを追加できます。
# ここでは、簡単な飲食店リストを DataFrame で作り、地図に可視化してみます。

# %% [markdown]
# ### 4.1 DataFrame を作成してマッピング

# %%
df_spots = pd.DataFrame({
    "name": ["カフェA", "レストランB", "ベーカリーC"],
    "lat": [35.130, 35.135, 35.125],
    "lon": [136.920, 136.930, 136.928],
    "category": ["cafe", "restaurant", "bakery"],
})

df_spots
# Out:
#      name     lat      lon    category
# 0    カフェA  35.130  136.920        cafe
# 1  レストランB  35.135  136.930  restaurant
# 2  ベーカリーC  35.125  136.928      bakery

# %%
m = folium.Map(location=center, zoom_start=13)

for _, row in df_spots.iterrows():
    folium.Marker(
        location=[row["lat"], row["lon"]],
        popup=f'{row["name"]} ({row["category"]})',
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_787fce13a148e7c822ec7a8c857ab702 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_787fce13a148e7c822ec7a8c857ab702&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_787fce13a148e7c822ec7a8c857ab702 = L.map(
#                 &quot;map_787fce13a148e7c822ec7a8c857ab702&quot;,
#                 {
#                     center: [35.133, 136.9264],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_29d834883715e2b2fbd6aae3e47f3647 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_29d834883715e2b2fbd6aae3e47f3647.addTo(map_787fce13a148e7c822ec7a8c857ab702);
#
#
#             var marker_4222fc5d60f28e5692ffb49763edfe49 = L.marker(
#                 [35.13, 136.92],
#                 {
# }
#             ).addTo(map_787fce13a148e7c822ec7a8c857ab702);
#
#
#         var popup_f0b09b61fc4217892a90b6cc25fe4163 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f28b4921105197326a0e90e366621d82 = $(`&lt;div id=&quot;html_f28b4921105197326a0e90e366621d82&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;カフェA (cafe)&lt;/div&gt;`)[0];
#                 popup_f0b09b61fc4217892a90b6cc25fe4163.setContent(html_f28b4921105197326a0e90e366621d82);
#
#
#
#         marker_4222fc5d60f28e5692ffb49763edfe49.bindPopup(popup_f0b09b61fc4217892a90b6cc25fe4163)
#         ;
#
#
#
#
#             var marker_7e64a92b394de8f90447f96f5b0e1ae8 = L.marker(
#                 [35.135, 136.93],
#                 {
# }
#             ).addTo(map_787fce13a148e7c822ec7a8c857ab702);
#
#
#         var popup_615b7762fe8897a941e32a3092d7c9a6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_61509eaab716aeeeb47ea61005c0b536 = $(`&lt;div id=&quot;html_61509eaab716aeeeb47ea61005c0b536&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;レストランB (restaurant)&lt;/div&gt;`)[0];
#                 popup_615b7762fe8897a941e32a3092d7c9a6.setContent(html_61509eaab716aeeeb47ea61005c0b536);
#
#
#
#         marker_7e64a92b394de8f90447f96f5b0e1ae8.bindPopup(popup_615b7762fe8897a941e32a3092d7c9a6)
#         ;
#
#
#
#
#             var marker_adc6869f6e74e044448ae9fb186f4965 = L.marker(
#                 [35.125, 136.928],
#                 {
# }
#             ).addTo(map_787fce13a148e7c822ec7a8c857ab702);
#
#
#         var popup_b315c85c957be562bcd8c1c9871ef529 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_332dcacac5479f601417d651f32ff708 = $(`&lt;div id=&quot;html_332dcacac5479f601417d651f32ff708&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ベーカリーC (bakery)&lt;/div&gt;`)[0];
#                 popup_b315c85c957be562bcd8c1c9871ef529.setContent(html_332dcacac5479f601417d651f32ff708);
#
#
#
#         marker_adc6869f6e74e044448ae9fb186f4965.bindPopup(popup_b315c85c957be562bcd8c1c9871ef529)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 4章 練習問題
#
# 1. 独自の DataFrame（例：コンビニ、スーパー、病院など）を作成し、カテゴリ情報も含めてマーカーに表示しなさい。
# 2. カテゴリごとにマーカーの色を変えたい場合、どのようなロジックで `folium.Icon(color=...)` を指定すればよいか考えなさい。
# 3. 緯度・経度だけでなく、`url` 列を持たせ、ポップアップ内にリンク（HTML）を埋め込むこともできます。HTML 文字列を popup に与える方法を調べて試してみなさい。

# %% [markdown]
# ## 5. タイルレイヤ（地図のデザイン）を変える
#
# folium では、OpenStreetMap のほかにもさまざまなタイルレイヤを利用できます。
# `folium.Map` の `tiles` 引数で指定します。
#
# 例：
# - `"OpenStreetMap"`
# - `"CartoDB positron"`
# - `"CartoDB dark_matter"`
# - `"CartoDB positron"` など

# %% [markdown]
# ### 5.1 タイルを変えてみる例

# %%
tiles_list = ["OpenStreetMap", "CartoDB positron", "CartoDB dark_matter"]

maps = []
for t in tiles_list:
    m = folium.Map(location=center, zoom_start=12, tiles=t)
    maps.append(m)

# 最初のマップを表示（必要に応じて maps[1], maps[2] なども評価してみてください）
maps[0]
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_68376789dba153e2c9f282835ec0950a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_68376789dba153e2c9f282835ec0950a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_68376789dba153e2c9f282835ec0950a = L.map(
#                 &quot;map_68376789dba153e2c9f282835ec0950a&quot;,
#                 {
#                     center: [35.133, 136.9264],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_676cacbbc1c6de494a880c1f1fa6d4d6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_676cacbbc1c6de494a880c1f1fa6d4d6.addTo(map_68376789dba153e2c9f282835ec0950a);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 5章 練習問題
#
# 1. `tiles` に `"CartoDB positron"` を指定して地図を表示し、標準との見た目の違いを確認しなさい。
# 2. 教育・プレゼン用途で使うとき、どのようなタイルデザインが適切か、自分の使い方を想像して考えを述べなさい。
# 3. 背景地図の著作権表示（クレジット）は通常どう扱われているか、folium / Leaflet の表示を見て確認しなさい。

# %% [markdown]
# ## 6. GeoJSON レイヤの表示
#
# **GeoJSON** は、地理情報（ポイント・ライン・ポリゴンなど）を表現するための JSON 形式です。
# folium では、`folium.GeoJson` を使って GeoJSON データを地図に重ねて表示できます。
#
# ここでは、簡単なポリゴン（四角形）の GeoJSON をコード内に直接書いて表示してみます。

# %% [markdown]
# ### 6.1 シンプルなポリゴン GeoJSON の例

# %%
# 非常に簡略化された四角形ポリゴン（名古屋市立大学経済学部付近のどこか）
simple_geojson = {
    "type": "FeatureCollection",
    "features": [
        {
            "type": "Feature",
            "properties": {"name": "サンプルエリア"},
            "geometry": {
                "type": "Polygon",
                "coordinates": [[
                    [136.920, 35.130],
                    [136.933, 35.130],
                    [136.933, 35.125],
                    [136.920, 35.125],
                    [136.920, 35.130]
                ]]
            }
        }
    ]
}

m = folium.Map(location=center, zoom_start=14)
folium.GeoJson(simple_geojson, name="geojson").add_to(m)
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_01d7418dc664d9a6872cbf364a2f3129 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_01d7418dc664d9a6872cbf364a2f3129&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_01d7418dc664d9a6872cbf364a2f3129 = L.map(
#                 &quot;map_01d7418dc664d9a6872cbf364a2f3129&quot;,
#                 {
#                     center: [35.133, 136.9264],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5f05f28865ca9b560b69c8d2aff477c8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5f05f28865ca9b560b69c8d2aff477c8.addTo(map_01d7418dc664d9a6872cbf364a2f3129);
#
#
#
#         function geo_json_3ec9e22780aac5e41468084b6bdaff01_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_3ec9e22780aac5e41468084b6bdaff01 = L.geoJson(null, {
#                 onEachFeature: geo_json_3ec9e22780aac5e41468084b6bdaff01_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_3ec9e22780aac5e41468084b6bdaff01_add (data) {
#             geo_json_3ec9e22780aac5e41468084b6bdaff01
#                 .addData(data);
#         }
#             geo_json_3ec9e22780aac5e41468084b6bdaff01_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[136.92, 35.13], [136.933, 35.13], [136.933, 35.125], [136.92, 35.125], [136.92, 35.13]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;\u30b5\u30f3\u30d7\u30eb\u30a8\u30ea\u30a2&quot;}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#         geo_json_3ec9e22780aac5e41468084b6bdaff01.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_3ec9e22780aac5e41468084b6bdaff01.addTo(map_01d7418dc664d9a6872cbf364a2f3129);
#
#
#             var layer_control_6f4c64c10af6417c242afea2da23a69a_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_5f05f28865ca9b560b69c8d2aff477c8,
#                 },
#                 overlays :  {
#                     &quot;geojson&quot; : geo_json_3ec9e22780aac5e41468084b6bdaff01,
#                 },
#             };
#             let layer_control_6f4c64c10af6417c242afea2da23a69a = L.control.layers(
#                 layer_control_6f4c64c10af6417c242afea2da23a69a_layers.base_layers,
#                 layer_control_6f4c64c10af6417c242afea2da23a69a_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_01d7418dc664d9a6872cbf364a2f3129);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 6章 練習問題
#
# 1. 自分で簡単なポリゴン（四角形や三角形）GeoJSON を作成し、色を変えて表示しなさい（`style_function` を使うと色指定ができます）。
# 2. 市区町村の境界 GeoJSON ファイルを入手した場合、JupyterLite にアップロードして `folium.GeoJson` で表示する手順を文章で説明しなさい。
# 3. ポリゴンにマウスを乗せたときに名前を表示するなど、インタラクティブな効果を付けたい場合、どのような拡張が考えられるか調べてみなさい。

# %% [markdown]
# ## 7. 総合ミニ演習：店舗マップ / 観光マップを作る
#
# 最後に、これまで学んだ内容を組み合わせて、
# 自分だけの「店舗マップ」や「観光マップ」を作ってみましょう。

# %% [markdown]
# ### 演習 1：自分の生活圏マップ
#
# 1. 自宅、よく行くスーパー、コンビニ、駅、カフェなど 5〜10 箇所の地点情報（名称・緯度・経度）を DataFrame やリストで作成しなさい。
# 2. folium を使って、これらの地点にマーカーを立てた地図を作成しなさい。
# 3. `popup` や `tooltip` に、その場所に対する自分のコメント（例：安い・静か・お気に入りなど）を加えなさい。
# 4. コードと地図のスクリーンショットをレポートなどに載せることを想定し、説明文をまとめてみなさい。

# %% [markdown]
# ### 演習 2：観光案内マップ
#
# 1. ある都市（例：名古屋、京都、大阪など）を 1 つ選び、主要な観光スポットや駅、ホテルなど 5〜10 箇所をピックアップしなさい。
# 2. 観光スポットごとにカテゴリ（寺社仏閣、博物館、グルメ、自然など）を設定し、カテゴリ別にマーカーの色やアイコンを変えることを検討しなさい。
# 3. 地図上でスポットを眺めながら、「どの順番で回ると効率が良さそうか」「どのエリアにスポットが集中しているか」などを考察し、文章にまとめなさい。

# %% [markdown]
# ---
#
# これで、JupyterLite 上での **Leaflet / folium 入門チュートリアル** は終了です。
#
# folium は、pandas や statsmodels と同様に、
# データ分析の結果を **地図上に可視化するための強力なツール** です。
#
# ぜひ、実際のデータ（例：調査地点、店舗売上、交通量、センサデータなど）にも応用してみてください。
